# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dates = pd.date_range('1/1/2000',periods=500)

# %%
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2001-05-05', '2001-05-06', '2001-05-07', '2001-05-08',
#                '2001-05-09', '2001-05-10', '2001-05-11', '2001-05-12',
#                '2001-05-13', '2001-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
col_D = np.random.rand(500)
print(col_D)
# Out:
# [0.71893701 0.81861519 0.19752259 0.84873395 0.99692493 0.7897369
#  0.02396816 0.30135512 0.65225231 0.30575197 0.78065514 0.64252546
#  0.77519733 0.77389492 0.0567471  0.05580767 0.88983328 0.59159507
#  0.06581841 0.57345802 0.54410463 0.22113762 0.9583142  0.64466553
#  0.42220976 0.16947303 0.30778585 0.7598974  0.05777655 0.70981721
#  0.91813559 0.13944569 0.89257995 0.86742071 0.84905126 0.76843013
#  0.52010054 0.20833997 0.26420431 0.09305789 0.28909533 0.4486046
#  0.45051008 0.13360922 0.21342778 0.66911078 0.16056968 0.63395356
#  0.500322   0.24618604 0.83239078 0.96802499 0.53737864 0.9427322
#  0.12384619 0.83019702 0.13095482 0.42132836 0.95340324 0.90657152
#  0.59234996 0.70117542 0.32734504 0.30965265 0.39923216 0.70343393
#  0.56306013 0.11601113 0.98355633 0.69790448 0.6340103  0.42105761
#  0.80854429 0.46106585 0.52967862 0.78515334 0.7235695  0.8396555
#  0.54799649 0.04848713 0.77941855 0.32110268 0.69638406 0.12309277
# ...

# %%
data1 = np.random.randn(500,3)
print(data1)
# Out:
# [[ 0.40268432  0.13534175 -0.78362915]
#  [-0.11311208  0.73571149 -1.03169729]
#  [-2.30885011 -0.70592432 -0.55701611]
#  ...
#  [ 2.39366885  0.09539737  0.34605963]
#  [ 0.07500203 -0.07780428  0.39498529]
#  [ 0.19858457 -1.03739182  1.59334456]]

# %%
df1 = pd.DataFrame(data=data1,index=dates,columns = ['A','B','C'])

# %%
df1.head()
# Out:
#                    A         B         C
# 2000-01-01  0.402684  0.135342 -0.783629
# 2000-01-02 -0.113112  0.735711 -1.031697
# 2000-01-03 -2.308850 -0.705924 -0.557016
# 2000-01-04  1.000797 -1.674903  1.600660
# 2000-01-05  1.626035 -1.334385  0.197873

# %%
df1['D'] = col_D

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.402684  0.135342 -0.783629  0.718937
# 2000-01-02 -0.113112  0.735711 -1.031697  0.818615
# 2000-01-03 -2.308850 -0.705924 -0.557016  0.197523
# 2000-01-04  1.000797 -1.674903  1.600660  0.848734
# 2000-01-05  1.626035 -1.334385  0.197873  0.996925

# %%
data2 = np.random.rand(20,3)
col= ['X','Y','Z']
df2 = pd.DataFrame(data=data2,columns=col)
df2.head()
# Out:
#           X         Y         Z
# 0  0.460932  0.224683  0.561931
# 1  0.573214  0.793281  0.845202
# 2  0.953380  0.327819  0.459277
# 3  0.651571  0.703441  0.008923
# 4  0.916093  0.024770  0.081219

# %% [markdown]
# <h2>Histogram</h2>

# %%
df1['A'].hist(bins=50)

# %%
df1['A'].plot(kind='hist',bins=50)

# %%
#Style sheet for matplotlib
plt.style.use('ggplot')

# %%
df1['A'].plot(kind='hist',bins=50)

# %%
plt.style.use('bmh')
df1['A'].plot(kind='hist',bins=50)

# %%
plt.style.use('dark_background')
df1['A'].plot(kind='hist',bins=50)

# %%
plt.style.use('fivethirtyeight')
df1['A'].plot(kind='hist',bins=50)

# %%
plt.style.use('ggplot')

# %%
df2.plot(kind='area',alpha=0.5)

# %%
df2.plot.area(alpha=0.5)

# %% [markdown]
# <h2>Bar Plots</h2>

# %%
df2.plot(kind='bar')

# %%
df2.plot(kind='barh')

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.hist(bins = 30,alpha=0.5)

# %%
df1.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2001-05-05', '2001-05-06', '2001-05-07', '2001-05-08',
#                '2001-05-09', '2001-05-10', '2001-05-11', '2001-05-12',
#                '2001-05-13', '2001-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
df1.plot.hist(stacked=True)

# %%
df1.plot.hist(stacked=True,orientation='horizontal',alpha=0.5)

# %%
df1.plot(y='B',figsize=(12,3),lw=1.5)

# %% [markdown]
# <h2>Scatter Plot </h2>

# %%
df1.plot.scatter(x='A',y='B')

# %%
ax = df1.plot.scatter(x='A',y='B',color='Green',label='Group1')
df1.plot.scatter(x='C',y='D',color='Blue',ax=ax,label='Group2')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm',s=50)

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# C:\Users\Wechuli\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# <h2>Box Plot</h2>

# %%
df2.plot.box()

# %%
df2.plot.box(vert=False)

# %%
color = dict(boxes='DarkGreen',whiskers='DarkOrange',medians='DarkBlue',caps='Grey')

# %%
df2.plot.box(color=color)

# %%
df2['group'] = np.random.choice(['A','B'],size=20)

# %%
df2.head()
# Out:
#           X         Y         Z group
# 0  0.460932  0.224683  0.561931     B
# 1  0.573214  0.793281  0.845202     B
# 2  0.953380  0.327819  0.459277     A
# 3  0.651571  0.703441  0.008923     A
# 4  0.916093  0.024770  0.081219     A

# %%
df2.boxplot(column=['X','Y'],by='group')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000231F9ED9B38>,
# ...
#       dtype=object)

# %%
df2.drop('group',axis=1,inplace=True
        )

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.460932  0.224683  0.561931
# 1  0.573214  0.793281  0.845202
# 2  0.953380  0.327819  0.459277
# 3  0.651571  0.703441  0.008923
# 4  0.916093  0.024770  0.081219

# %%
df1.plot.hexbin(x='A',y='B',gridsize=25,cmap='Oranges')

# %% [markdown]
# <h2>KDE Plot</h2>

# %%
df2['X'].plot.kde()

# %%
df2['X'].plot.density()

# %%
df2.plot.kde()

# %% [markdown]
# <h2>Pie Plots</h2>

# %%
df2.plot.pie(y='X',figsize=(4,4),legend=False)

# %%
df2.plot.pie(subplots=True,figsize=(12,4),legend=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000231FC096240>,
# ...
#       dtype=object)
