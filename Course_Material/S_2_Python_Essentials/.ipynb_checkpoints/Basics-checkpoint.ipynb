# %%
print('My name is {} and my age is {}'.format('Paul',25))
# Out:
# My name is Paul and my age is 25

# %%
print('Her name is {name} and her age is {age}'.format(name='June',age=22))
# Out:
# Her name is June and her age is 22

# %%
print('My name is {name} and {name} and age is {age}, yes {age}'.format(name='Wechuli',age=25))
# Out:
# My name is Wechuli and Wechuli and age is 25, yes 25

# %%
mystring = 'This is a long string'

# %%
mystring[6]
# Out:
# 's'

# %%
mystring[6]='r'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-69b91c117a5f> in <module>()
# ----> 1 mystring[6]='r'
#
# TypeError: 'str' object does not support item assignment

# %%
mystring[-1]
# Out:
# 'g'

# %%
mystring[:4]
# Out:
# 'This'

# %%
mystring[3:6]
# Out:
# 's i'

# %% [markdown]
# String methods

# %%
greeting = 'Hi, my name is Paul'

# %%
greeting.lower()
# Out:
# 'hi, my name is paul'

# %%
greeting.upper()
# Out:
# 'HI, MY NAME IS PAUL'

# %%
greeting.split()
# Out:
# ['Hi,', 'my', 'name', 'is', 'Paul']

# %%
tweet = 'go flames go! #hoockey'

# %%
tweet.split('#')[1]
# Out:
# 'hoockey'

# %% [markdown]
# lists

# %%
fruits = ['bananas','oranges','apples','guavas','mangoes']

# %%
fruits
# Out:
# ['bananas', 'oranges', 'apples', 'guavas', 'mangoes']

# %%
len(fruits)
# Out:
# 5

# %%
for item in fruits:
    print(item)
# Out:
# bananas
# oranges
# apples
# guavas
# mangoes

# %%
fruits[1:2]
# Out:
# ['oranges']

# %%
fruits.append('Pineapples')

# %%
fruits
# Out:
# ['bananas', 'oranges', 'apples', 'guavas', 'mangoes', 'Pineapples']

# %%
fruits.pop()
# Out:
# 'Pineapples'

# %%
fruits
# Out:
# ['bananas', 'oranges', 'apples', 'guavas', 'mangoes']

# %%
nested_fruits = ['Avacado','Peacheas']

# %%
fruits.append(nested_fruits)

# %%
fruits
# Out:
# ['bananas', 'oranges', 'apples', 'guavas', 'mangoes', ['Avacado', 'Peacheas']]

# %%
fruits[5][1]
# Out:
# 'Peacheas'

# %%
max([2,3,4,6])
# Out:
# 6

# %% [markdown]
# Dictionaries

# %%
mydict = {"k1":'v1','k2':'v2','k3':'v3'}

# %%
mydict['k4']='v4'

# %%
mydict
# Out:
# {'k1': 'v1', 'k2': 'v2', 'k3': 'v3', 'k4': 'v4'}

# %%
mydict['k1']
# Out:
# 'v1'

# %%
mydict.values
# Out:
# <function dict.values>

# %%
mydict.values()
# Out:
# dict_values(['v1', 'v2', 'v3'])

# %%
mydict.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %% [markdown]
# Tuples - imutable

# %%
mytuple = (1,2,3)

# %%
mytuple[1
       ]
# Out:
# 2

# %% [markdown]
# Sets

# %%
myset = {3,2,34,4,2,23,3,2,2,2,2,2}

# %%
print(myset)
# Out:
# {2, 3, 34, 4, 23}

# %%
s={1,2,3}

# %%
s.add(5)

# %%
s
# Out:
# {1, 2, 3, 5}

# %%
s.add(5)

# %%
s
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# Boolean

# %%
she_loves_me = False

# %%
if(she_loves_me):
    print('You are good to go')
else:
    print('Better luck next time')
# Out:
# Better luck next time
