# %% [markdown]
# <a href='http://www.scienceacademy.ca'> <img style="float: left;height:70px" src="Log_SA.jpeg"></a>

# %% [markdown]
# # [Audio_editing](https://support.udemy.com/hc/en-us/articles/229605128-Audio-Issues-What-is-Background-Noise-)
# # [iMovie_Background noise reduction](https://www.youtube.com/watch?v=wH2zJh8NjSU)

# %% [markdown]
# So we have deleted the col_1 using inplace = True, let's get that column back into our dataframe. We can simply run the cell where we created the dataframe in the begining to get the dataframe into its original state with three columns col_1, col_2 and col_3. Actually I need all three columns in the next example.

# %% [markdown]
# ## [Distribution Plots](http://seaborn.pydata.org/tutorial/distributions.html#distribution-tutorial): <font style="font-size:16px;color:green;">Visualizing the distribution of a dataset</font>
#
# <br>
# **[A Good Resource](https://pythonprogramming.net)**<br>
#
# ### How this is tuple unpacking in the following matplotlib command [fig, axes = plt.subplots(1, 2)](https://python-forum.io/Thread-Tuple-Unpacking-with-graphs-in-matplotlib)

# %% [markdown]
# &#9758;
#
# &#9989;
#
# [Symbols html codes](https://www.w3schools.com/charsets/ref_utf_symbols.asp)
#
# [Reading space or tab saperated file in pandas](https://stackoverflow.com/questions/22809061/read-space-separated-data-with-pandas?noredirect=1&lq=1)

# %% [markdown]
# Image from web:
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/41/Comparison_of_1D_histogram_and_KDE.png" >

# %% [markdown]
# # Quicktime tricks
# file --> new screen recording<br>
# escape to display the control on screen<br>
# option and then pause will appear <br>
# to restart recording, just record with pressing any button

# %% [markdown]
# ### [Installing Python Packages from a Jupyter Notebook](https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/)

# %%
import sys
print(sys.executable)
# Out:
# /anaconda/bin/python

# %%
#!pip

# %%
#!pip freeze

# %%
#!pip install plotly

# %%
from plotly import __version__
print(__version__)
# Out:
# 2.4.1

# %%
#!pip install cufflinks

# %%
from cufflinks import __version__
print(__version__)
# Out:
# 0.12.1

# %%
#!conda env list

# %% [markdown]
# [Jupyter note book data_rate_isse answered](https://github.com/jupyter/notebook/issues/3010)<br>
# Start notebook on the terminal using:<br>
# `jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000`

# %% [markdown]
# [2015 Global Open Data Index](https://www.kaggle.com/okfn/open-data/data)<br>
# [World Happiness Report](https://www.kaggle.com/unsdsn/world-happiness/data)<br>
# [S&P 500 stock data](https://www.kaggle.com/camnugent/sandp500/data)<br>
# [Commercial Bank Failures, 1934-Present](https://www.kaggle.com/fdic/bank-failures/data)<br>
# [Red Wine quality dataset - regression and classification - claen](https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009/data)<br>
# [Boston Housing Dataset](https://www.kaggle.com/heptapod/uci-ml-datasets/data)<br>
# [Boston Housing Dataset link-2](https://www.kaggle.com/sukeshpabba/linear-regression-with-boston-housing-data/data)<br>
# [Breast Cancer Wisconsin (Prognostic) Data Set](https://www.kaggle.com/sarahvch/breast-cancer-wisconsin-prognostic-data-set/data)<br>
# [Gender Classification](https://www.kaggle.com/hb20007/gender-classification/data)<br>
# [German Credit Risk_1 no target](https://www.kaggle.com/uciml/german-credit/data)<br>
# [German Credit Risk_2 with target](https://www.kaggle.com/kabure/german-credit-data-with-risk/data)<br>
# [Breast Cancer Wisconsin (Diagnostic) Data Set](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/data)<br>

# %% [markdown]
# # [OpenML_Datasets](https://www.openml.org/search?type=data)
# # [R Datasets](https://vincentarelbundock.github.io/Rdatasets/datasets.html)
# # [ML DataSets](https://archive.ics.uci.edu/ml/datasets.html)
# # [UCI Datasets](https://archive.ics.uci.edu/ml/datasets.html)
# # [MachineLearningMastery](https://machinelearningmastery.com)

# %% [markdown]
# ## [Galton Work -- Regression Inventor](http://www.galton.org/bibliography/index.html)
# ### [Galton’s Family Heights Data Revisited by Hao Han, Stony Brook Univ.](https://arxiv.org/pdf/1508.02942.pdf)
# ### [Galton Original Work Link 1](http://galton.org/essays/1880-1889/galton-1886-jaigi-regression-stature.pdf)
# ### [Galton Original Work Link 2](http://www.stat.ucla.edu/~nchristo/statistics100C/history_regression.pdf)
# ### [Galton Data Plots-analys](https://rstudio-pubs-static.s3.amazonaws.com/204984_dd2112475db84af2a03260c4a4f830ac.html)

# %% [markdown]
# ## [Data.World DataSet](https://data.world)
# [CancerReg.csv](https://data.world/exercises/linear-regression-exercise-1/workspace/file?filename=cancer_reg.csv)<br>
# [Thi_Visit_Visas - Monthly number of tourist visas issued separated by region and nationality, for the period 2010-2016](https://data.world/payapdatasci/thai-tourism/workspace/file?filename=thaitourism2.csv)

# %%
#!pip install pandas-datareader

# %% [markdown]
# [Confusion Matrix](http://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/)<br>
# [Curse of Dimensionality](http://www.visiondummy.com/2014/04/curse-dimensionality-affect-classification/#The_curse_of_dimensionality_and_overfitting)<br>
# **Sparsity -- ** more scattered - Lower number density e.g. hair sparsity increases with age]<br>
# [Sparse_Matrix](https://en.wikipedia.org/wiki/Sparse_matrix)<br>
# [KNN_Netflix_Prize](http://cs.carleton.edu/cs_comps/0910/netflixprize/final_results/knn/index.html)<br>
# [KNN_Variable_Standardization](http://www.scholarpedia.org/article/K-nearest_neighbor)--[StackExchange_link](https://stats.stackexchange.com/questions/287425/why-do-you-need-to-scale-data-in-knn)<br>
#
# ### Tree Methods
# [Hitters Salary dataset](https://github.com/JWarmenhoven/ISLR-python/blob/master/Notebooks/Data/Hitters.csv)

# %% [markdown]
# # [ISLR-Python](https://github.com/JWarmenhoven/ISLR-python)<br>
# [DataSets used in the book](https://github.com/JWarmenhoven/ISLR-python/tree/master/Notebooks/Data)
# ### Tree Methods
# [Hitters Salary dataset](https://github.com/JWarmenhoven/ISLR-python/blob/master/Notebooks/Data/Hitters.csv)<br>
# [Excellent Link for Entropy and Information Gain for tree splitting](https://stackoverflow.com/questions/1859554/what-is-entropy-and-information-gain)<br>
# [Another on splitting](https://www.quora.com/In-a-decision-tree-how-do-we-select-which-attribute-to-split-the-data-by-at-each-level)<br>
# [Very Good Slides on Entropy and Information Gain](https://homes.cs.washington.edu/~shapiro/EE596/notes/InfoGain.pdf)<br>
# [Random Forests A good tutorial](https://www.inertia7.com/projects/95#intro)<br>
# [Random Decision Forests by Tin Kam Ho in 1995](http://ect.bell-labs.com/who/tkh/publications/papers/odt.pdf)<br>
#
# ### SVM's
# [SVM - Kernel trick](http://beta.cambridgespark.com/courses/jpm/05-module.html)<br>
#
#
# ### K-Mean -- Unsupervised Machine Learning
# [Delivery Driver Example and a good explanation](https://www.datascience.com/blog/k-means-clustering)<br>
#
# ### PCA
# [Practical Guide to Principal Component Analysis (PCA](https://www.analyticsvidhya.com/blog/2016/03/practical-guide-principal-component-analysis-python/)
#
# ### NPL
# [Natural Language Processing in Python -- Good tutorial](https://www.analyticsvidhya.com/blog/2017/01/ultimate-guide-to-understand-implement-natural-language-processing-codes-in-python/)

# %%
#! pip install pandas

# %%
#!pip install pandas-datareader

# %%
#!pip install Quandl

# %%
import bpy
numcubes = 6 
rcubes = 0.3 
for x in range(numcubes):
    for y in range(numcubes):
        for z in range(numcubes):
            bpy.ops.mesh.primitive_cube_add(
                radius=rcubes, location = (x,y,z)
            )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2055d3531c9a> in <module>()
# ----> 1 import bpy
#       2 numcubes = 6
#       3 rcubes = 0.3
#       4 for x in range(numcubes):
#       5     for y in range(numcubes):
#
# ModuleNotFoundError: No module named 'bpy'

# %%
# !pip install --upgrade pip
# Out:
# ...
#     100% |████████████████████████████████| 1.4MB 382kB/s ta 0:00:011
# ...
#   Found existing installation: pip 9.0.1
#     Uninstalling pip-9.0.1:
#       Successfully uninstalled pip-9.0.1
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, combinations
# %matplotlib inline

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect("equal")

# draw cube
r = [-1, 1]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
    if np.sum(np.abs(s-e)) == r[1]-r[0]:
        ax.plot3D(*zip(s, e), color="b")

# draw sphere
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax.plot_wireframe(x, y, z, color="r")

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, combinations
# %matplotlib inline

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect("equal")

# draw cube
r = [-1, 1]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
    if np.sum(np.abs(s-e)) == r[1]-r[0]:
        ax.plot3D(*zip(s, e), color="r")

# %%
# !pip install pydot
